# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv
from datetime import datetime
import scipy.stats as st
from scipy.stats import linregress


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
countries = []
locations = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    
    # If the city is unique, then add it to a our cities list
    if (city not in cities):
        cities.append(city)
        countries.append(country)

#print(cities)
#print(countries)
city_count = len(cities)
print(city_count)
# Out:
# 602

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
params = {
    "q": "",
    "units": "imperial",
    "appid": weather_api_key
}
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

cloudy = []
date = []
humid = []
lat = []
lng = []
max_temp = []
wind_speed = []
valid_cities = []
valid_countries = []
humid_per = []
cloud_per = []
current_date = []
log_file = open("../output_data/citylog.txt","w") 
for i in range(0,city_count):
    params["q"] = str(cities[i]) + "," + str(countries[i])
    response = requests.get(url, params)
    #print(response.url)
    data = response.json()
    #print(data)
    if(data['cod']!= "404"):
        log_text = f"Processing City " +str(i)+" with id "+str(data['id'])+" | "+str(cities[i])
        print(log_text)
        #city_writer.writerow(log_text)
        log_file.writelines(log_text)
        log_file.write("\n")
        valid_cities.append(data['name'])
        valid_countries.append(data['sys']['country'])
        cloudy.append(data['clouds']['all'])
        date.append(data['dt'])
        humid.append(data['main']['humidity'])
        lat.append(data['coord']['lat'])
        lng.append(data['coord']['lon'])
        max_temp.append(data['main']['temp_max'])
        wind_speed.append(data['wind']['speed'])
        ts = int(data['dt'])
        current_date = datetime.utcfromtimestamp(ts).strftime('%m/%d/%Y')        
    else:
        print(f"City not found")

log_file.close()
print(f"-----------------------------")
print(f"Data Retrieval Complete")      
print(f"-----------------------------")
print(f"Current Date:"+str(current_date))

col_names = ['City', 'Cloudiness', 'Country', 'Date', 'Humidity', 'Lat','Lng', 'Max Temp', 'Wind Speed']
data = list(zip(valid_cities, cloudy, valid_countries, date, humid, lat, lng, max_temp, wind_speed))
#print(data)
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing City 0 with id 1512205 | abaza
# Processing City 1 with id 1268865 | jodhpur
# Processing City 2 with id 3899695 | ancud
# Processing City 3 with id 2077963 | albany
# City not found
# Processing City 5 with id 2015306 | tiksi
# Processing City 6 with id 2630299 | hofn
# Processing City 7 with id 1507390 | dikson
# Processing City 8 with id 3369157 | cape town
# Processing City 9 with id 2144528 | warrnambool
# Processing City 10 with id 2163355 | hobart
# Processing City 11 with id 6167817 | torbay
# Processing City 12 with id 5972762 | hay river
# Processing City 13 with id 2028164 | deputatskiy
# City not found
# Processing City 15 with id 6185377 | yellowknife
# Processing City 16 with id 5379533 | orange cove
# Processing City 17 with id 3833367 | ushuaia
# Processing City 18 with id 3698705 | cascas
# City not found
# Processing City 20 with id 3728097 | les cayes
# City not found
# Processing City 22 with id 4020109 | atuona
# Processing City 23 with id 5848280 | kapaa
# Processing City 24 with id 3381041 | mana
# Processing City 25 with id 2122783 | katangli
# Processing City 26 with id 2155415 | new norfolk
# Processing City 27 with id 2729907 | longyearbyen
# Processing City 28 with id 217562 | butembo
# Processing City 29 with id 4030556 | rikitea
# Processing City 30 with id 3698359 | chicama
# Processing City 31 with id 3424607 | tasiilaq
# Processing City 32 with id 4032243 | vaini
# Processing City 33 with id 5866583 | kodiak
# City not found
# Processing City 35 with id 2455290 | kidal
# Processing City 36 with id 780643 | bjornevatn
# Processing City 37 with id 1015776 | bredasdorp
# Processing City 38 with id 3664980 | boa vista
# Processing City 39 with id 2063036 | port lincoln
# Processing City 40 with id 2137773 | vao
# Processing City 41 with id 5880054 | barrow
# Processing City 42 with id 964432 | port alfred
# City not found
# Processing City 44 with id 1259312 | yerraguntla
# Processing City 45 with id 60019 | eyl
# Processing City 46 with id 6089245 | norman wells
# City not found
# City not found
# Processing City 49 with id 3373652 | oistins
# Processing City 50 with id 3370903 | jamestown
# Processing City 51 with id 6620339 | karratha
# Processing City 52 with id 3402648 | carutapera
# Processing City 53 with id 3573061 | saint george
# Processing City 54 with id 1646448 | cimahi
# Processing City 55 with id 6170031 | tuktoyaktuk
# Processing City 56 with id 8079926 | labuhan
# Processing City 57 with id 2075265 | busselton
# Processing City 58 with id 922015 | acoua
# Processing City 59 with id 1180289 | dera ghazi khan
# Processing City 60 with id 1623197 | tual
# Processing City 61 with id 1267390 | kavaratti
# City not found
# Processing City 63 with id 5563839 | fortuna
# Processing City 64 with id 3577154 | oranjestad
# Processing City 65 with id 2206939 | bluff
# Processing City 66 with id 1006984 | east london
# City not found
# City not found
# City not found
# Processing City 70 with id 3471451 | arraial do cabo
# Processing City 71 with id 1631637 | pemangkat
# Processing City 72 with id 965528 | phalaborwa
# Processing City 73 with id 2074865 | carnarvon
# Processing City 74 with id 2121385 | severo-kurilsk
# Processing City 75 with id 610611 | aqtobe
# Processing City 76 with id 3356213 | khorixas
# Processing City 77 with id 546105 | nikolskoye
# Processing City 78 with id 3347762 | lubango
# Processing City 79 with id 3874787 | punta arenas
# City not found
# Processing City 81 with id 2112802 | hasaki
# Processing City 82 with id 1835848 | seoul
# Processing City 83 with id 3421765 | nanortalik
# Processing City 84 with id 2126682 | bilibino
# Processing City 85 with id 6255012 | flinders
# Processing City 86 with id 5666176 | miles city
# Processing City 87 with id 1731298 | aloleng
# Processing City 88 with id 178443 | wajir
# Processing City 89 with id 6096551 | pangnirtung
# Processing City 90 with id 3418910 | upernavik
# Processing City 91 with id 3987246 | san felipe
# Processing City 92 with id 4033557 | tautira
# Processing City 93 with id 359792 | aswan
# City not found
# Processing City 95 with id 3423146 | ilulissat
# Processing City 96 with id 2152667 | portland
# Processing City 97 with id 3366880 | hermanus
# Processing City 98 with id 2027044 | batagay
# Processing City 99 with id 3985710 | cabo san lucas
# Processing City 100 with id 5855927 | hilo
# Processing City 101 with id 1633070 | palembang
# Processing City 102 with id 358620 | safaga
# Processing City 103 with id 2065594 | mount isa
# Processing City 104 with id 741240 | of
# Processing City 105 with id 2161515 | kiama
# Processing City 106 with id 64814 | bandarbeyla
# Processing City 107 with id 3407762 | amapa
# Processing City 108 with id 556268 | ostrovnoy
# Processing City 109 with id 3932145 | pisco
# Processing City 110 with id 3459943 | jequie
# Processing City 111 with id 2015179 | tommot
# City not found
# Processing City 113 with id 5374920 | morro bay
# Processing City 114 with id 5847411 | kahului
# Processing City 115 with id 933995 | souillac
# Processing City 116 with id 607610 | zhanaozen
# Processing City 117 with id 2281951 | sassandra
# City not found
# Processing City 119 with id 3123493 | ferrol
# Processing City 120 with id 2180815 | tuatapere
# Processing City 121 with id 1282256 | hithadhoo
# Processing City 122 with id 3624593 | buenos aires
# Processing City 123 with id 4035715 | avarua
# Processing City 124 with id 1803782 | lichuan
# Processing City 125 with id 3984997 | san quintin
# Processing City 126 with id 2411397 | georgetown
# Processing City 127 with id 1529484 | hami
# Processing City 128 with id 2208248 | kaitangata
# Processing City 129 with id 1784055 | zhuanghe
# Processing City 130 with id 3395503 | maraba
# Processing City 131 with id 1262380 | musiri
# Processing City 132 with id 2070998 | geraldton
# Processing City 133 with id 3403687 | camocim
# City not found
# Processing City 135 with id 6165406 | thompson
# Processing City 136 with id 2654970 | brae
# Processing City 137 with id 108410 | riyadh
# Processing City 138 with id 3578441 | saint-francois
# Processing City 139 with id 3896218 | castro
# Processing City 140 with id 3831208 | qaanaaq
# Processing City 141 with id 1648082 | boyolangu
# Processing City 142 with id 2121025 | srednekolymsk
# Processing City 143 with id 3419842 | sisimiut
# Processing City 144 with id 3573374 | the valley
# Processing City 145 with id 3421719 | narsaq
# Processing City 146 with id 6078372 | moose factory
# Processing City 147 with id 3671450 | inirida
# Processing City 148 with id 3372707 | ribeira grande
# City not found
# Processing City 150 with id 2274275 | robertsport
# Processing City 151 with id 5030005 | hibbing
# Processing City 152 with id 3393692 | itarema
# Processing City 153 with id 2123814 | leningradskiy
# Processing City 154 with id 3939168 | huarmey
# Processing City 155 with id 3421982 | maniitsoq
# Processing City 156 with id 2071860 | esperance
# Processing City 157 with id 3443061 | chuy
# Processing City 158 with id 1529102 | urumqi
# Processing City 159 with id 527321 | mezen
# Processing City 160 with id 2126199 | cherskiy
# Processing City 161 with id 5367788 | lompoc
# Processing City 162 with id 2017155 | saskylakh
# Processing City 163 with id 3141667 | roald
# Processing City 164 with id 5983720 | iqaluit
# Processing City 165 with id 1651461 | amuntai
# Processing City 166 with id 2121909 | poronaysk
# City not found
# Processing City 168 with id 1591474 | bac lieu
# Processing City 169 with id 1525988 | ayagoz
# Processing City 170 with id 3617154 | puerto cabezas
# Processing City 171 with id 3380402 | saint-georges
# Processing City 172 with id 2094342 | kavieng
# Processing City 173 with id 3867291 | filadelfia
# City not found
# Processing City 175 with id 4026082 | lazaro cardenas
# Processing City 176 with id 3694112 | paita
# Processing City 177 with id 3883457 | lebu
# Processing City 178 with id 1526384 | almaty
# Processing City 179 with id 3670218 | san andres
# Processing City 180 with id 3374210 | sao filipe
# Processing City 181 with id 2110227 | butaritari
# Processing City 182 with id 2022572 | khatanga
# Processing City 183 with id 2126123 | chokurdakh
# Processing City 184 with id 3472404 | alvorada
# Processing City 185 with id 3347019 | namibe
# Processing City 186 with id 3386213 | touros
# City not found
# Processing City 188 with id 347634 | tahta
# Processing City 189 with id 978895 | margate
# Processing City 190 with id 236901 | ouadda
# City not found
# Processing City 192 with id 6185021 | wynyard
# Processing City 193 with id 3651949 | san cristobal
# Processing City 194 with id 3894426 | coihaique
# Processing City 195 with id 6137462 | saint-augustin
# Processing City 196 with id 3408424 | ipixuna
# Processing City 197 with id 2112309 | katsuura
# Processing City 198 with id 3770066 | san luis
# Processing City 199 with id 2013727 | vanavara
# Processing City 200 with id 3506630 | el penon
# Processing City 201 with id 286621 | salalah
# Processing City 202 with id 2013639 | verkhnevilyuysk
# Processing City 203 with id 1106677 | bambous virieux
# Processing City 204 with id 3652764 | puerto ayora
# Processing City 205 with id 3380290 | sinnamary
# Processing City 206 with id 658288 | heinola
# Processing City 207 with id 1515029 | ulaangom
# Processing City 208 with id 2158767 | mareeba
# Processing City 209 with id 1489828 | teeli
# Processing City 210 with id 1528998 | yumen
# Processing City 211 with id 3066095 | sitborice
# Processing City 212 with id 3012649 | issy-les-moulineaux
# Processing City 213 with id 4003938 | jimenez
# Processing City 214 with id 934322 | mahebourg
# Processing City 215 with id 286245 | sur
# Processing City 216 with id 4031574 | provideniya
# City not found
# City not found
# Processing City 219 with id 5282297 | bethel
# Processing City 220 with id 5554428 | ketchikan
# City not found
# Processing City 222 with id 3379507 | bartica
# Processing City 223 with id 962367 | richards bay
# Processing City 224 with id 3412093 | vestmannaeyjar
# Processing City 225 with id 4031742 | egvekinot
# Processing City 226 with id 3466165 | cidreira
# Processing City 227 with id 538138 | kuvandyk
# City not found
# Processing City 229 with id 4174600 | sweetwater
# Processing City 230 with id 2122090 | pevek
# Processing City 231 with id 3456248 | nortelandia
# Processing City 232 with id 777019 | vardo
# Processing City 233 with id 3572627 | cockburn town
# Processing City 234 with id 4470244 | havelock
# Processing City 235 with id 1624041 | ternate
# Processing City 236 with id 3653967 | muisne
# Processing City 237 with id 3430863 | mar del plata
# Processing City 238 with id 364933 | umm kaddadah
# Processing City 239 with id 2028028 | aksha
# City not found
# Processing City 241 with id 3103824 | barlinek
# Processing City 242 with id 1337607 | kudahuvadhoo
# Processing City 243 with id 1812101 | dongying
# Processing City 244 with id 490276 | sosnovka
# Processing City 245 with id 2092164 | lorengau
# Processing City 246 with id 3397763 | jacareacanga
# Processing City 247 with id 2309332 | ebebiyin
# Processing City 248 with id 2445704 | diffa
# Processing City 249 with id 1218612 | murgab
# Processing City 250 with id 3414079 | olafsvik
# Processing City 251 with id 2629833 | husavik
# Processing City 252 with id 5126209 | mastic beach
# Processing City 253 with id 4034551 | faanui
# Processing City 254 with id 2527087 | tiznit
# City not found
# City not found
# Processing City 257 with id 2156643 | mount gambier
# City not found
# Processing City 259 with id 156124 | kyaka
# Processing City 260 with id 1791464 | wenling
# Processing City 261 with id 2645198 | kirkwall
# Processing City 262 with id 4036284 | alofi
# Processing City 263 with id 1106643 | quatre cocos
# Processing City 264 with id 5505411 | henderson
# Processing City 265 with id 876177 | luau
# Processing City 266 with id 3662927 | pauini
# Processing City 267 with id 2657782 | aberystwyth
# Processing City 268 with id 1630789 | pontianak
# Processing City 269 with id 5924351 | clyde river
# Processing City 270 with id 2428394 | mao
# Processing City 271 with id 5975004 | high level
# Processing City 272 with id 3451138 | rio grande
# Processing City 273 with id 935215 | saint-philippe
# Processing City 274 with id 2986626 | plouzane
# Processing City 275 with id 5919850 | chapais
# Processing City 276 with id 694016 | shyryayeve
# Processing City 277 with id 2122605 | okhotsk
# Processing City 278 with id 5445298 | dodge city
# Processing City 279 with id 1510377 | belyy yar
# Processing City 280 with id 501847 | rochegda
# Processing City 281 with id 3452085 | queimadas
# Processing City 282 with id 2447513 | arlit
# Processing City 283 with id 2511180 | santa cruz de la palma
# Processing City 284 with id 1517637 | ushtobe
# Processing City 285 with id 4580575 | greenwood
# Processing City 286 with id 214974 | kalemie
# Processing City 287 with id 612053 | senaki
# Processing City 288 with id 1028434 | quelimane
# City not found
# City not found
# Processing City 291 with id 4465088 | elizabeth city
# Processing City 292 with id 540259 | krym
# Processing City 293 with id 1489401 | toora-khem
# Processing City 294 with id 2014833 | tura
# Processing City 295 with id 1502073 | krasnoselkup
# Processing City 296 with id 495904 | shamary
# Processing City 297 with id 2013375 | vitim
# Processing City 298 with id 5710035 | west wendover
# City not found
# Processing City 300 with id 2212775 | sabha
# Processing City 301 with id 3372964 | lagoa
# Processing City 302 with id 4021858 | guerrero negro
# Processing City 303 with id 4820938 | saint albans
# Processing City 304 with id 3663684 | labrea
# Processing City 305 with id 3394372 | morros
# Processing City 306 with id 2192362 | christchurch
# Processing City 307 with id 371745 | kutum
# Processing City 308 with id 935616 | le port
# Processing City 309 with id 2172797 | cairns
# Processing City 310 with id 219057 | binga
# City not found
# Processing City 312 with id 5583997 | ammon
# Processing City 313 with id 2025456 | chernyshevskiy
# Processing City 314 with id 5000950 | marquette
# Processing City 315 with id 2409914 | bonthe
# Processing City 316 with id 1171868 | loralai
# Processing City 317 with id 2208425 | zuwarah
# Processing City 318 with id 2025579 | chegdomyn
# Processing City 319 with id 664910 | tismana
# Processing City 320 with id 1265888 | kovur
# Processing City 321 with id 5961417 | gimli
# Processing City 322 with id 5984000 | iroquois falls
# Processing City 323 with id 2109528 | buala
# Processing City 324 with id 192202 | kijabe
# Processing City 325 with id 5850554 | makakilo city
# Processing City 326 with id 3374218 | santa maria
# Processing City 327 with id 3137469 | sorland
# Processing City 328 with id 1650434 | bambanglipuro
# Processing City 329 with id 3723593 | jeremie
# Processing City 330 with id 1488903 | turukhansk
# Processing City 331 with id 5870133 | nome
# City not found
# Processing City 333 with id 2610343 | vestmanna
# Processing City 334 with id 933366 | maun
# Processing City 335 with id 2541479 | nador
# Processing City 336 with id 777682 | skjervoy
# Processing City 337 with id 1636308 | manokwari
# Processing City 338 with id 3393471 | oriximina
# Processing City 339 with id 3621607 | santa cruz
# City not found
# Processing City 341 with id 778707 | mehamn
# Processing City 342 with id 1283285 | jumla
# Processing City 343 with id 2015608 | tambovka
# Processing City 344 with id 2122104 | petropavlovsk-kamchatskiy
# Processing City 345 with id 2032614 | baruun-urt
# Processing City 346 with id 5380437 | pacific grove
# City not found
# Processing City 348 with id 3430443 | necochea
# City not found
# Processing City 350 with id 1855540 | naze
# Processing City 351 with id 2093846 | kiunga
# City not found
# Processing City 353 with id 2026160 | borogontsy
# Processing City 354 with id 3569907 | saint-pierre
# Processing City 355 with id 1808316 | yiyang
# Processing City 356 with id 2120591 | tilichiki
# Processing City 357 with id 2013279 | vostok
# City not found
# Processing City 359 with id 3355672 | luderitz
# Processing City 360 with id 1698289 | pundaguitan
# Processing City 361 with id 1684245 | tagusao
# Processing City 362 with id 3870243 | taltal
# Processing City 363 with id 986717 | kruisfontein
# Processing City 364 with id 6355222 | yulara
# Processing City 365 with id 3442206 | juan lacaze
# Processing City 366 with id 2134814 | sola
# Processing City 367 with id 2400547 | gamba
# Processing City 368 with id 2012780 | zabaykalsk
# Processing City 369 with id 2789715 | opglabbeek
# Processing City 370 with id 112656 | tonekabon
# Processing City 371 with id 2181625 | te anau
# Processing City 372 with id 3665210 | rodrigues alves
# Processing City 373 with id 1181636 | chakwal
# Processing City 374 with id 2013942 | ust-karsk
# Processing City 375 with id 3351663 | benguela
# Processing City 376 with id 2141305 | fayaoue
# Processing City 377 with id 3374083 | bathsheba
# Processing City 378 with id 2206874 | waipawa
# Processing City 379 with id 3372988 | horta
# Processing City 380 with id 505820 | povenets
# Processing City 381 with id 244878 | biltine
# Processing City 382 with id 2278158 | buchanan
# Processing City 383 with id 3385899 | tutoia
# Processing City 384 with id 1649150 | bengkulu
# Processing City 385 with id 1850523 | tateyama
# Processing City 386 with id 2446796 | bilma
# Processing City 387 with id 5779548 | payson
# Processing City 388 with id 3393536 | olinda
# Processing City 389 with id 100926 | umm lajj
# Processing City 390 with id 4031637 | lavrentiya
# Processing City 391 with id 7671223 | kloulklubed
# City not found
# Processing City 393 with id 2274895 | monrovia
# City not found
# Processing City 395 with id 3374346 | ponta do sol
# City not found
# Processing City 397 with id 566157 | divnomorskoye
# Processing City 398 with id 3448903 | sao joao da barra
# City not found
# Processing City 400 with id 6111862 | port hardy
# Processing City 401 with id 3374336 | porto novo
# Processing City 402 with id 1814093 | dali
# Processing City 403 with id 1274359 | chhapar
# City not found
# Processing City 405 with id 645765 | muhos
# City not found
# Processing City 407 with id 3395458 | maragogi
# Processing City 408 with id 2164422 | griffith
# Processing City 409 with id 110690 | abha
# Processing City 410 with id 3445026 | vila velha
# Processing City 411 with id 2012530 | zhigansk
# Processing City 412 with id 2304548 | anloga
# Processing City 413 with id 1071296 | antalaha
# Processing City 414 with id 3860443 | comodoro rivadavia
# Processing City 415 with id 3496332 | salcedo
# Processing City 416 with id 2055868 | yantal
# Processing City 417 with id 2699282 | kristinehamn
# Processing City 418 with id 2219235 | awbari
# Processing City 419 with id 1791779 | wanning
# Processing City 420 with id 2141722 | bouloupari
# Processing City 421 with id 2194098 | ahipara
# Processing City 422 with id 2222230 | sangmelima
# Processing City 423 with id 2019488 | namtsy
# Processing City 424 with id 2173911 | broken hill
# City not found
# Processing City 426 with id 6050066 | la ronge
# City not found
# Processing City 428 with id 483341 | ternovka
# Processing City 429 with id 6148373 | sioux lookout
# Processing City 430 with id 5803139 | mercer island
# Processing City 431 with id 3662395 | santo antonio do ica
# Processing City 432 with id 3491355 | black river
# Processing City 433 with id 3132644 | varhaug
# Processing City 434 with id 1540711 | muravlenko
# Processing City 435 with id 2276492 | harper
# Processing City 436 with id 160141 | dunda
# Processing City 437 with id 945945 | upington
# City not found
# Processing City 439 with id 218680 | boende
# City not found
# City not found
# Processing City 442 with id 4355594 | frederick
# Processing City 443 with id 1803886 | lianran
# City not found
# Processing City 445 with id 3401148 | cururupu
# Processing City 446 with id 3382226 | camopi
# City not found
# Processing City 448 with id 2012728 | zakamensk
# Processing City 449 with id 1184845 | ahmadpur east
# Processing City 450 with id 2132606 | samarai
# Processing City 451 with id 5557293 | sitka
# Processing City 452 with id 1267579 | kashipur
# Processing City 453 with id 964420 | port elizabeth
# Processing City 454 with id 2165478 | gladstone
# Processing City 455 with id 5344157 | dublin
# City not found
# City not found
# Processing City 458 with id 2064550 | northam
# Processing City 459 with id 1272864 | dharchula
# Processing City 460 with id 1852357 | shimoda
# Processing City 461 with id 2512186 | puerto del rosario
# Processing City 462 with id 2075720 | broome
# Processing City 463 with id 3397865 | itaueira
# Processing City 464 with id 3381428 | iracoubo
# Processing City 465 with id 2145554 | ulladulla
# Processing City 466 with id 3388456 | sao jose da coroa grande
# Processing City 467 with id 3454061 | peruibe
# Processing City 468 with id 4449620 | vicksburg
# Processing City 469 with id 3870282 | talcahuano
# Processing City 470 with id 1737486 | bintulu
# Processing City 471 with id 1719246 | candoni
# Processing City 472 with id 1627035 | simpang
# Processing City 473 with id 1045114 | inhambane
# Processing City 474 with id 2177069 | ballina
# Processing City 475 with id 5404476 | ukiah
# Processing City 476 with id 2026786 | berezovyy
# Processing City 477 with id 2286304 | korhogo
# Processing City 478 with id 1337606 | eydhafushi
# Processing City 479 with id 2122493 | omsukchan
# Processing City 480 with id 1640902 | kawalu
# Processing City 481 with id 525426 | sobolevo
# Processing City 482 with id 3464262 | encruzilhada
# Processing City 483 with id 2287778 | jacqueville
# Processing City 484 with id 935221 | saint-paul
# Processing City 485 with id 3391889 | pitimbu
# Processing City 486 with id 3382160 | cayenne
# Processing City 487 with id 343134 | awash
# Processing City 488 with id 1255619 | srivardhan
# City not found
# Processing City 490 with id 3663142 | novo aripuana
# Processing City 491 with id 2704613 | hudiksvall
# City not found
# Processing City 493 with id 5983607 | inuvik
# Processing City 494 with id 3902685 | eucaliptus
# Processing City 495 with id 487495 | sterlitamak
# Processing City 496 with id 5859699 | college
# Processing City 497 with id 2126710 | beringovskiy
# Processing City 498 with id 1266164 | kopaganj
# Processing City 499 with id 1503796 | khandagayty
# City not found
# Processing City 501 with id 1525798 | balkhash
# Processing City 502 with id 293992 | ofaqim
# Processing City 503 with id 3532592 | atlixco
# Processing City 504 with id 2120612 | tigil
# City not found
# Processing City 506 with id 5992154 | kindersley
# Processing City 507 with id 1822207 | sisophon
# Processing City 508 with id 6113406 | prince rupert
# Processing City 509 with id 2136825 | isangel
# Processing City 510 with id 2206900 | westport
# Processing City 511 with id 5554072 | juneau
# City not found
# Processing City 513 with id 2173323 | bundaberg
# Processing City 514 with id 3470137 | belmonte
# Processing City 515 with id 4034307 | mahina
# Processing City 516 with id 2128975 | nemuro
# Processing City 517 with id 2964782 | dingle
# Processing City 518 with id 178073 | wundanyi
# Processing City 519 with id 2063042 | port hedland
# City not found
# Processing City 521 with id 6533368 | moranbah
# Processing City 522 with id 1259385 | port blair
# Processing City 523 with id 5985918 | jasper
# Processing City 524 with id 361058 | alexandria
# Processing City 525 with id 3381303 | kourou
# Processing City 526 with id 1718367 | carlagan
# Processing City 527 with id 2309528 | luba
# Processing City 528 with id 1213855 | sibolga
# Processing City 529 with id 101628 | tabuk
# Processing City 530 with id 2618795 | klaksvik
# City not found
# Processing City 532 with id 1862505 | hirara
# Processing City 533 with id 1491267 | sosva
# Processing City 534 with id 2112444 | kamaishi
# Processing City 535 with id 6171633 | ucluelet
# Processing City 536 with id 5955902 | fort nelson
# Processing City 537 with id 2189343 | kaeo
# Processing City 538 with id 6160919 | taber
# Processing City 539 with id 2022083 | kirensk
# Processing City 540 with id 934479 | grand gaube
# Processing City 541 with id 5178800 | back mountain
# Processing City 542 with id 2191562 | dunedin
# Processing City 543 with id 779622 | havoysund
# Processing City 544 with id 5882953 | aklavik
# Processing City 545 with id 1856392 | muroto
# Processing City 546 with id 5503914 | fallon
# Processing City 547 with id 2514651 | los llanos de aridane
# Processing City 548 with id 5106279 | west milford
# Processing City 549 with id 5454627 | alamogordo
# City not found
# Processing City 551 with id 612592 | oni
# Processing City 552 with id 1054329 | vangaindrano
# Processing City 553 with id 2155858 | nambucca heads
# Processing City 554 with id 158514 | kaliua
# City not found
# Processing City 556 with id 2834629 | schwedt
# Processing City 557 with id 1735227 | kuantan
# Processing City 558 with id 4015700 | cananea
# Processing City 559 with id 3893629 | coquimbo
# Processing City 560 with id 5024719 | duluth
# Processing City 561 with id 1788852 | xining
# Processing City 562 with id 5384339 | port hueneme
# Processing City 563 with id 2018735 | nyurba
# Processing City 564 with id 2027296 | aykhal
# City not found
# Processing City 566 with id 3462315 | governador valadares
# Processing City 567 with id 5927969 | corner brook
# Processing City 568 with id 905846 | mpika
# Processing City 569 with id 1816751 | beidao
# Processing City 570 with id 3573197 | hamilton
# Processing City 571 with id 5970873 | hare bay
# Processing City 572 with id 4344819 | waggaman
# Processing City 573 with id 917748 | choma
# City not found
# Processing City 575 with id 3461408 | ilheus
# Processing City 576 with id 6145563 | shawville
# Processing City 577 with id 370481 | marawi
# Processing City 578 with id 2524928 | corleone
# Processing City 579 with id 3839307 | rawson
# Processing City 580 with id 3571913 | marsh harbour
# Processing City 581 with id 2090021 | namatanai
# Processing City 582 with id 1310120 | mawlaik
# Processing City 583 with id 3500957 | la romana
# Processing City 584 with id 2090495 | morehead
# Processing City 585 with id 161616 | balkanabat
# Processing City 586 with id 1735799 | sri aman
# Processing City 587 with id 1327659 | chauk
# Processing City 588 with id 625721 | lyuban
# Processing City 589 with id 1488429 | uray
# Processing City 590 with id 5359864 | isla vista
# City not found
# Processing City 592 with id 1328421 | pathein
# City not found
# Processing City 594 with id 57000 | hobyo
# Processing City 595 with id 331259 | mega
# Processing City 596 with id 543246 | kozhva
# Processing City 597 with id 1504019 | kazanskoye
# Processing City 598 with id 3466980 | caravelas
# City not found
# Processing City 600 with id 5563397 | eureka
# Processing City 601 with id 1516048 | hovd
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Current Date:03/17/2020

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Output File (CSV)
city_weather_file = "../output_data/cities.csv"
with open('../output_data/cities.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(col_names)
    writer.writerows(data)

# %%
# Create a Data Frame
weather_df = pd.read_csv(city_weather_file)
#print(weather_df)
display(weather_df)
print(weather_df.count())
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0         Abaza         100      RU  1584468904        87  52.66   90.09
# 1       Jodhpur          17      IN  1584468904        22  26.29   73.03
# 2         Ancud          40      CL  1584468904        67 -41.87  -73.82
# 3        Albany          17      AU  1584468904        81 -35.02  117.89
# 4         Tiksi          84      RU  1584468905        88  71.69  128.87
# ..          ...         ...     ...         ...       ...    ...     ...
# 528      Kozhva          82      RU  1584468987        89  65.11   57.05
# 529  Kazanskoye          50      RU  1584468987        82  55.64   69.23
# 530   Caravelas           9      BR  1584468689        73 -17.71  -39.25
# 531      Eureka          90      US  1584468863        70  40.80 -124.16
# 532       Khovd          17      MN  1584468987        47  48.01   91.64
#
#      Max Temp  Wind Speed
# 0       29.39        4.41
# 1       75.65       10.49
# 2       60.80        6.93
# 3       53.60       10.29
# 4      -30.73        8.37
# ..        ...         ...
# 528     21.65       10.71
# 529     26.33       17.94
# 530     81.77        8.84
# 531     46.40        6.93
# 532     28.13        2.30
#
# [533 rows x 9 columns]
# City          533
# Cloudiness    533
# Country       531
# Date          533
# Humidity      533
# Lat           533
# Lng           533
# Max Temp      533
# Wind Speed    533
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
lat = weather_df['Lat']
max_temp = weather_df['Max Temp']
plt.figure(figsize=(8, 6))
plt.scatter(lat,max_temp, marker="o", c="red", edgecolors= "black", s=40)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title(f"City Latitude Vs Max Temperature "+"("+str(current_date)+")", fontsize=14)
plt.grid(True)
plt.savefig("../output_data/Lat_Temp_Plot.png")
plt.show()

# %% [markdown]
# There appears to be a linear decrease in temperature with the increase in latitude as we move north from the equator.
# However, for the cities in southern hemisphere we do not see much of a decrease in temperature moving south of the equator to around -40F.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
humid_per = weather_df['Humidity']
plt.figure(figsize=(8, 6))
plt.scatter(lat,humid_per, marker="o", c="green", edgecolors= "black", s=40)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude Vs Humidity  "+"("+str(current_date)+")", fontsize=14)
plt.grid(True)
plt.savefig("../output_data/Lat_Humid_Plot.png")
plt.show()

# %% [markdown]
# There does not seem to be a strong correlation between latitude and humidity.However, it appears that of all the cities considered, more cities have a humidity above 60%.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
cloud_per = weather_df['Cloudiness']
plt.figure(figsize=(8, 6))
plt.scatter(lat,cloud_per, marker="o", c="cyan", edgecolors= "black", s=40)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude Vs Cloudiness  "+"("+str(current_date)+")", fontsize=14)
plt.grid(True)
plt.savefig("../output_data/Lat_Cloud_Plot.png")
plt.show()

# %% [markdown]
# For the cities considered, latitude and cloudiness do not seem to be correlated much. We do notice a collection of close data points at various cloudiness % levels (0%,20%,40%,70% and 100%) regardless of latitude.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
wind_speed = weather_df['Wind Speed']
plt.figure(figsize=(8, 6))
plt.scatter(lat,wind_speed, marker="o", c="blue", edgecolors= "black", s=40)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude Vs Wind Speed "+"("+str(current_date)+")", fontsize=14)
plt.grid(True)
plt.savefig("../output_data/Lat_Wind_Plot.png")
plt.show()

# %% [markdown]
# Similarly, there seems to be no correlation between Wind Speed and Latitude for the cities considered. One thing to note is that for a majority of the cities in both the hemispheres, the wind speed seems to fall in the range of 0-10 mph.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
# Calculate the correlation coefficient and linear regression model 
def linear_regress_plot(col1,col2,x_loc,y_loc):
    correlation = st.pearsonr(col1,col2)
    print(f"The correlation between both factors is {round(correlation[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(col1, col2)
    regress_values = col1 * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.figure(figsize=(8, 6))
    plt.scatter(col1,col2,s=40, c='blue',edgecolors='black')
    plt.plot(col1,regress_values,"r-",color='red')
    plt.annotate(line_eq,(x_loc,y_loc),fontsize=15,color="black")

# %%
# Create Northern and Southern Hemisphere DataFrames
north_hemi_df = weather_df[weather_df['Lat'] >= 0]
#print(north_hemi_df)
display(north_hemi_df)
south_hemi_df = weather_df[weather_df['Lat'] < 0]
#print(south_hemi_df)
display(south_hemi_df)
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0         Abaza         100      RU  1584468904        87  52.66   90.09
# 1       Jodhpur          17      IN  1584468904        22  26.29   73.03
# 4         Tiksi          84      RU  1584468905        88  71.69  128.87
# 5          Hofn          20      IS  1584468905        64  64.25  -15.21
# 6        Dikson         100      RU  1584468905        96  73.51   80.55
# ..          ...         ...     ...         ...       ...    ...     ...
# 527        Mēga          72      ET  1584468987        47   4.05   38.30
# 528      Kozhva          82      RU  1584468987        89  65.11   57.05
# 529  Kazanskoye          50      RU  1584468987        82  55.64   69.23
# 531      Eureka          90      US  1584468863        70  40.80 -124.16
# 532       Khovd          17      MN  1584468987        47  48.01   91.64
#
#      Max Temp  Wind Speed
# 0       29.39        4.41
# 1       75.65       10.49
# 4      -30.73        8.37
# 5       35.60       11.41
# 6        3.47       10.36
# ..        ...         ...
# 527     76.01        9.57
# 528     21.65       10.71
# 529     26.33       17.94
# 531     46.40        6.93
# 532     28.13        2.30
#
# [358 rows x 9 columns]
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 2          Ancud          40      CL  1584468904        67 -41.87  -73.82
# 3         Albany          17      AU  1584468904        81 -35.02  117.89
# 7      Cape Town          13      ZA  1584468874        82 -33.93   18.42
# 8    Warrnambool          93      AU  1584468905        47 -38.38  142.48
# 9         Hobart         100      AU  1584468774        52 -42.88  147.33
# ..           ...         ...     ...         ...       ...    ...     ...
# 509       Ilhéus          20      BR  1584468984        74 -14.79  -39.05
# 513       Rawson           0      AR  1584468984        72 -43.30  -65.10
# 515    Namatanai          96      PG  1584468985        78  -3.67  152.43
# 518     Morehead          79      PG  1584468985        97  -8.71  141.64
# 530    Caravelas           9      BR  1584468689        73 -17.71  -39.25
#
#      Max Temp  Wind Speed
# 2       60.80        6.93
# 3       53.60       10.29
# 7       68.00       12.75
# 8       73.00       14.27
# 9       69.01        9.17
# ..        ...         ...
# 509     86.00       10.29
# 513     60.89       15.90
# 515     81.77       12.73
# 518     73.13        2.75
# 530     81.77        8.84
#
# [175 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linear_regress_plot(north_hemi_df['Lat'],north_hemi_df['Max Temp'],10,19)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.savefig("../output_data/North_Temp_Lat_Plot.png")
plt.show()
# Out:
# The correlation between both factors is -0.9

# %% [markdown]
# In the northern hemisphere, there seems to be a strong negative linear correlation between latitude and maximum temperature of a city. A r squared value of -0.9 suggests that cities with higher values of latitude are associated with lower values of maximum temperature. In other words,that as the latitude increases, the maximum temperature of a city seems to decrease.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linear_regress_plot(south_hemi_df['Lat'],south_hemi_df['Max Temp'],-25,45)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.savefig("../output_data/South_Temp_Lat_Plot.png")
plt.show()
# Out:
# The correlation between both factors is 0.66

# %% [markdown]
# In the southern hemisphere, there seems to be moderate positive relationship between latitude and max temperature of a city. A r squared value of 0.66 suggests that cities with higher values of latitude (closer to the equator) are associated with higher values of maximum temperature.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_regress_plot(north_hemi_df['Lat'],north_hemi_df['Humidity'],50,18)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.savefig("../output_data/North_Humid_Lat_Plot.png")
plt.show()
# Out:
# The correlation between both factors is 0.32

# %% [markdown]
# This scatter plot shows a weaker relationship between temperature and humidity in the northern hemishphere, with an r-squared value of 0.3.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_regress_plot(south_hemi_df['Lat'],south_hemi_df['Humidity'],-50,20)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.savefig("../output_data/South_Humid_Lat_Plot.png")
plt.show()
# Out:
# The correlation between both factors is 0.21

# %% [markdown]
# Similar to the nothern hemisphere, there seems be a weaker relationship between temperature and humidity in the southern hemishphere too, with an r-squared value of 0.2

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_regress_plot(north_hemi_df['Lat'],north_hemi_df['Cloudiness'],45,50)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.savefig("../output_data/North_Cloud_Lat_Plot.png")
plt.show()
# Out:
# The correlation between both factors is 0.28

# %% [markdown]
# There does not seem to be a significant correlation between latitude and cloudiness in the northern hemisphere. The r-squared value of 0.28 shows there is a positive correlation between the two, but it is weak.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_regress_plot(south_hemi_df['Lat'],south_hemi_df['Cloudiness'],-55,53)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.savefig("../output_data/South_Cloud_Lat_Plot.png")
plt.show()
# Out:
# The correlation between both factors is 0.31

# %% [markdown]
# The scatter plot shows that there exists a weak positive correlation between latitude and cloudiness in the southern hemisphere as well(with an r-squared value of 0.3).

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_regress_plot(north_hemi_df['Lat'],north_hemi_df['Wind Speed'],17,27)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.savefig("../output_data/North_Wind_Lat_Plot.png")
plt.show()
# Out:
# The correlation between both factors is 0.04

# %% [markdown]
# There seems to be almost no correlation between latitude and wind speed with an r-squared value of 0.04, in the northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_regress_plot(south_hemi_df['Lat'],south_hemi_df['Wind Speed'],-45,25)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.savefig("../output_data/South_Wind_Lat_Plot.png")
plt.show()
# Out:
# The correlation between both factors is -0.3

# %% [markdown]
# However, in the southern hemishphere, a moderate to weak negative relationship seems to exist between the wind speed and latitude.Wind speed seems to increase as we move away from the equator.
